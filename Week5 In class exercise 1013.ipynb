# %% [markdown]
# 1. Make a function that can take any non-negative integer as an argument and return it with its digits in descending order. Essentially, rearrange the digits to create the highest possible number. If no number is passed in, make the default value inputted = 111111. Input = 43905 Output = 95430 Input = 584366 Output = 866543

# %%
# Here is my function
def Integer_sort(a=111111):
    if a > 0:
        return int("".join(sorted(str(a), reverse=True)))
    else:
        print("please enter a non-negative integer")

# Sample output
print(Integer_sort(43905))
print(Integer_sort(584366))
Integer_sort(-15)
# Out:
# 95430
# 866543
# please enter a non-negative integer

# %% [markdown]
# 2. Import jeopardy.csv and create a dataframe from the data. Find out the following:
# - How many rows are there in the dataframe? What does a row represent?
# - How many unique shows were there each year?
# - Think of another question that this data can help answer. Make that question a header in your notebook.
# - Answer your question and show the steps you used to do so clearly.

# %%
# Import libraries
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
jeopardy_data = "JEOPARDY_CSV.csv"

# Read Purchasing File and store into Pandas data frame
jeopardy_data_df = pd.read_csv(jeopardy_data)

# %%
# Explore data
jeopardy_data_df

# How many rows are there in the dataframe? What does a row represent?
#### This output shows that there are 216930 rows. 
#### Each row represents a question that was asked during a specific jeopardy episode
# Out:
#         Show Number    Air Date             Round  \
# 0              4680  12/31/2004         Jeopardy!
# 1              4680  12/31/2004         Jeopardy!
# 2              4680  12/31/2004         Jeopardy!
# 3              4680  12/31/2004         Jeopardy!
# 4              4680  12/31/2004         Jeopardy!
# ...             ...         ...               ...
# 216925         4999   5/11/2006  Double Jeopardy!
# 216926         4999   5/11/2006  Double Jeopardy!
# 216927         4999   5/11/2006  Double Jeopardy!
# 216928         4999   5/11/2006  Double Jeopardy!
# 216929         4999   5/11/2006   Final Jeopardy!
#
#                                Category    Value  \
# 0                               HISTORY    $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES    $200
# 2           EVERYBODY TALKS ABOUT IT...    $200
# 3                      THE COMPANY LINE    $200
# 4                   EPITAPHS & TRIBUTES    $200
# ...                                 ...      ...
# ...

# %%
# How many unique shows were there each year?

# First, parse out the 'year' from the Air date variable
years = pd.DatetimeIndex(jeopardy_data_df[' Air Date']).year

# Next, group this by 'years' (that we just created)
grouped_years = jeopardy_data_df.groupby(years)['Show Number']

# Find the unique per year
grouped_years.nunique()
# Out:
#  Air Date
# 1984     23
# 1985     16
# 1986     25
# 1987     22
# 1988     22
# 1989     36
# 1990     73
# 1991     24
# 1992     32
# 1993     35
# 1994     19
# 1995     19
# 1996     83
# 1997    221
# 1998    223
# 1999    229
# 2000    225
# 2001    203
# 2002    114
# 2003    158
# 2004    220
# 2005    225
# 2006    230
# 2007    231
# 2008    232
# 2009    226
# 2010    231
# 2011    224
# 2012     19
# Name: Show Number, dtype: int64

# %%
# Show as data frame
jeo_df = pd.DataFrame(grouped_years.nunique())
jeo_df
# Out:
#            Show Number
#  Air Date
# 1984                23
# 1985                16
# 1986                25
# 1987                22
# 1988                22
# 1989                36
# 1990                73
# 1991                24
# 1992                32
# 1993                35
# 1994                19
# 1995                19
# 1996                83
# 1997               221
# 1998               223
# 1999               229
# 2000               225
# 2001               203
# 2002               114
# 2003               158
# 2004               220
# 2005               225
# 2006               230
# 2007               231
# 2008               232
# 2009               226
# 2010               231
# 2011               224
# 2012                19

# %%
# Think of another question that this data can help answer. Make that question a header in your notebook.

# %% [markdown]
# ### Does Jeopardy ever repeat their questions?

# %%
# Answer your question and show the steps you used to do so clearly.

# Print number of unique questions
jeopardy_data_df[' Question'].nunique() # value is 216123
   ### Compare this number to the total rows from the previous question.

# Because there are 216,930 rows, but 216,123 unique questions, we know that Jeopardy must have recycled some questions
  ### in the past!
# Out:
# 216123

# %% [markdown]
# **3. Create any graph using matplotlib that helps you understand the jeopardy data. Explain what your graph shows and why it is useful.**

# %% [markdown]
# This graph shows the total Jeopardy shows per year. It is useful because we can quickly see how popular Jeopardy has been over time. We can also see which years were particularly successful.

# %%
import matplotlib.pyplot as plt

# %%
# Create the bar plot
jeo_df['Show Number'].plot(kind='bar', color='b', 
                                       xlabel='',
                                       ylabel='Total Number of Shows')
plt.xticks(rotation=90)
plt.title('Total Jeopardy Shows Per Year', fontsize=12, fontweight='bold')

# Display our chart
plt.show()
