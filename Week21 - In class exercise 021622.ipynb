# %% [markdown]
# # Week 21: In class exercise
# ### 02/16/2022

# %% [markdown]
# **1. Make sure you can get the API from class to work in Azure. Take a screenshot of it working and add the image to a jupyter notebook.**

# %% [markdown]
# ![helloworld.PNG](attachment:helloworld.PNG)

# %% [markdown]
# ![gdp.PNG](attachment:gdp.PNG)

# %% [markdown]
# ![year.PNG](attachment:year.PNG)

# %% [markdown]
# **2. Loop through the API data in python using the /gdp/<"year> endpoint for your API. What does it look like? Is there a way to alter the html page to simplify what you see?**

# %% [markdown]
# When I loop through the year end point, I simply see the data for that year (like in the screen shot above). The data are also formatted as a dictionary within a list, which isn't always the easiest to interpret. Instead, I printed the value of each dictionary key to simplify the above information a little bit. See screen shot below.

# %% [markdown]
# ![revised.PNG](attachment:revised.PNG)
